// %% [markdown]
// # Laboratorio Java: Foglio Esercizi 0

// %% [markdown]
// ### Ex 1: ...

// %%
System.out.println("Jupyter with Java! :D");
// Out:
// Jupyter with Java! :D

// %% [markdown]
// ### Ex 2: ...

// %% [markdown]
// ### Ex 3: ...

// %% [markdown]
// ### Ex 4: ...
